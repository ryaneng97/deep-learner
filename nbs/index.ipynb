# %%
#| hide
from deep_learner.core import *

# %% [markdown]
# # deep-learner
#
# > Deep Learner Framework

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install deep_learner in Development mode

# %% [markdown]
# ```sh
# # make sure deep_learner package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to deep_learner
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/ryaneng97/deep-learner.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c ryaneng97 deep_learner
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install deep_learner
# ```
#
#
# [repo]: https://github.com/ryaneng97/deep-learner
# [docs]: https://ryaneng97.github.io/deep-learner/
# [pypi]: https://pypi.org/project/deep-learner/
# [conda]: https://anaconda.org/ryaneng97/deep-learner

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/ryaneng97/deep-learner
# [docs]: https://ryaneng97.github.io/deep-learner/
# [pypi]: https://pypi.org/project/deep-learner/
# [conda]: https://anaconda.org/ryaneng97/deep-learner

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
